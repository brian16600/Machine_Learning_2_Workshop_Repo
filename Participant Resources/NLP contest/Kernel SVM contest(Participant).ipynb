# %% [markdown]
# # **Kernel SVM model for Covid-19**

# %% [markdown]
# ### How can NLP be used to identify social media posts that are relevant to Covid-19?

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Covid19_captions.tsv', delimiter = '\t', quoting = 3)

# %% [markdown]
# - tsv files contain elements seperated by tabs and csv files contain elements seperated by commas which can interfere with the commas within the text so we use tsv files for NLP
# - delimiter argument is used to specify to the read_csv method that this file is in tsv format
# - quoting = 3 is needed to ensure that the use of quotes in the text are not misinterpreted

# %% [markdown]
# ## Cleaning the texts

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
# this list will contain only the 'cleaned' words
for i in range(0, 34):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Captions'][i])
  # the 1st argument specifies what should be replaced, the 2nd one specifies the replacement term and the 3rd one specifies the location of the term
  review = review.lower()
  review = review.split()
  # this splitting is done to get individual words so that the stem method can be applied to each word
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Types of 'cleaning' done:
# - removal of stopwords(i.e. 'the', 'a', 'on')
# - retrieving the essence/base form of remaining words(i.e. 'love' instead of 'loved'
# - replacing of non-alphabetical features with spaces
# - uppercase to lower case

# %%
print(corpus)
# Out:
# ['guy seven billion covid vaccin dose administ global not vaccin live countri vaccin wide avail think excus anymor time see signific reaction larg amount vaccin would see alreadi hidden agenda', 'novemb mean month left also mean month accomplish goal far', 'multi ministri taskforc announc workforc vaccin measur keep workplac safe jan employe fulli vaccin recov covid within past day return workplac', 'updat safe manag measur take note head shop mall store effect oct let part build covid resili singapor', 'got booster vaccin shot today', 'got second covid vaccin jab today igotmyshot', 'work healthcar tire profess', 'share respons ensur sustain climat breathabl air futur gener', 'test neg covid arttest singapor', 'jordan lost job pandem not one lucki found mentalhealth support get difficult time need mental health care everyon everywher', 'billion peopl vision impair blind least billion could prevent yet address take care eye get check regularli', 'announc ministri health may regular surveil test roll set progress start student hostel autonom univers henc introduc regular fast easi test fet regim student staff pilot programm use antigen rapid test art self test kit start august implement pilot programm ad precaut safeguard health student staff enabl quick detect better contain commun spread viru event confirm covid case', 'get shot today slot avail book use link bio moderna pfizer vaccin high demand johnson johnson yet approv fda', 'work home setup risen demand sinc start pandem get wfh set right top line stand desk ergonom chair', 'singapor report new covid case weekli infect rate increas steadili safe manag measur set tighten', 'student miss psle paper due covid', 'punch way jet lag thank centrfit high intens train noth get long trip like punchi workout', 'novavax covid vaccin receiv first emerg use authoris', 'vaccin travel lane mean futur globe trot link bio', 'tire lockdown need take break constant work come visit zoo today', 'mask fatigu say tobia zambotti aleksisaa design wearabl puffer jacket made singl use mask coat comment environment issu caus pandem', 'tourist strand ejina banner due latest round coronaviru infect make heart shape leav train ejina banner alxa leagu north china inner mongolia autonom region', 'second dose astrazeneca covid vaccin done stay safe everyon', 'nasal spray flu vaccin nasal spray flu vaccin free nh children age year august born septemb august primari school children children secondari school children age year long term health condit', 'still amidst pandem extrem import us take care famili found one student famili covid send posit thought prayer', 'viru covid remain unbeaten sinc last year care everi day hear case surround us affect live economi', 'must protect viru one way wear face mask properli becom new norm stay safe top prioriti million live save wear face mask', 'custom import part busi know gener reach ideal custom lead masteri cours', 'kabosu turn year old rescu shiba inu chang world impromptu photoshoot back slightli rais eyebrow cross paw remain one greatest reaction imag time legend much wow', 'introduc chevrolet beast absolut insan road behemoth', 'hope approv give confid drive vaccin covid unfortun death compel driver', 'punch way jet lag thank centrfit high intens train noth get long trip like punchi workout', 'ladi gentlemen smoki one biggest tyre shredder hammerhead go read clown wheel circu pick novemb issu top gear magazin tap link bio detail', 'wow desanti seen light life save covid therapeut long desanti also promot vaccin finger cross not long']

# %% [markdown]
# ## Creating the Bag of Words model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ## Training the Kernel SVM model on the Training set

# %% [markdown]
# ![Screenshot 2022-01-24 at 10.41.52 PM.png](data:image/png;base64,...)

# %%
#!!!Type/Paste the code here!!!
# Out:
# SVC(random_state=0)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
